# %%
# The goal of this notebook will be to clean the 'coffee_origin' data in order to focus on 
# countries of origin for sourcing our coffee beans.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

coffee_origins = pd.read_csv('clean_coffee.csv', index_col=False)
coffee_origins = coffee_origins.drop('Unnamed: 0', axis=1)
coffee_origins.head()
# Out:
#                                 title  rating  aftertaste  aroma  body  \
# 0             Bolivia Manantial Gesha      93         8.0      9     8
# 1          Ethiopia Gera Genji Challa      94         8.0      9     9
# 2        Yirgacheffe Mengesha Natural      94         8.0      9     9
# 3  Tropical Summer Colombia La Sierra      93         8.0      9     8
# 4                     Tinamit Tolimán      93         8.0      9     9
#
#    flavor                                   blind_assessment  \
# 0       9  Richly aromatic, floral-toned. Magnolia, cocoa...
# 1       9  Delicately aromatic, complex. Lilac, cocoa nib...
# 2       9  High-toned, fruit-driven. Boysenberry, pear, c...
# 3       9  Fruit-driven, crisply chocolaty. Goji berry, d...
# 4       9  Deeply sweet-tart, chocolate-toned. Dark choco...
#
#                                        coffee_origin        est_price  \
# 0                                  Caranavi, Bolivia  30.00/12 ounces
# 1     Agaro Gera, Jimma Zone, Oromia State, Ethiopia  28.00/12 ounces
# 2      Yirgacheffe growing region, southern Ethiopia  20.50/12 ounces
# 3              La Sierra, Cauca Department, Colombia   18.99/8 ounces
# 4  San Lucas Tolimán, Lake Atitlán growing region...  16.00/12 ounces
#
#     roast_level                     roaster        roaster_location  \
# 0  Medium-Light  Red Rooster Coffee Roaster         Floyd, Virginia
# 1  Medium-Light               Mostra Coffee   San Diego, California
# 2  Medium-Light               Regent Coffee    Glendale, California
# 3  Medium-Light        Merge Coffee Company  Harrisonburg, Virginia
# 4  Medium-Light                El Gran Cafe      Antigua, Guatemala
#
#    dollars_per_ounce
# 0           2.500000
# 1           2.333333
# 2           1.708333
# 3           2.373750
# 4           1.333333

# %%
# It looks like the 'coffee_origin' column tends to have the country name as the last item listed.
coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.split(', ')
coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str[-1]
coffee_origins['coffee_origin'].head(15)
# Out:
# 0                   Bolivia
# 1                  Ethiopia
# 2         southern Ethiopia
# 3                  Colombia
# 4                 Guatemala
# 5                  Ethiopia
# 6                 Guatemala
# 7                  Colombia
# 8          Papua New Guinea
# 9         southern Ethiopia
# 10     northern Philippines
# 11                 Colombia
# 12                 Colombia
# 13        southern Ethiopia
# 14    Big Island of Hawai’i
# Name: coffee_origin, dtype: object

# %%
coffee_origins['coffee_origin'].unique()
# Whew! That's still a lot! Time to clean it up.
# Out:
# array(['Bolivia', 'Ethiopia', 'southern Ethiopia', 'Colombia',
#        'Guatemala', 'Papua New Guinea', 'northern Philippines',
#        'Big Island of Hawai’i', 'Brazil', 'Peru', 'Ethiopia; Sumatra',
#        'El Salvador', 'Southern Ethiopia', 'Tanzania', 'Kenya', 'Panama',
#        'Democratic Republic of the Congo', 'Costa Rica', 'Ecuador',
#        'southwest Vietnam', 'Indonesia', 'central El Salvador',
#        'Nicaragua', '“Big Island” of Hawai’i', 'Mexico', 'Rwanda',
#        'Haiti', 'Dominican Republic; Honduras', 'Vietnam',
#        'Thailand; Vietnam; Latin America', 'Not disclosed',
#        'south-central Kenya', 'northern Nicaragua', 'Burundi',
#        'Guatemala; Nicaragua; Ethiopia; Costa Rica; Indonesia; Brazil',
#        'Colombia; Ethiopia', 'Honduras', 'Colombia; Guatemala; Mexico',
#        'Guatemala; Ethiopia; Colombia', 'south-central Ethiopia',
#        'western Panama', 'Philippines', 'southern Colombia',
#        'Colombia; Guatemala; Costa Rica; Ethiopia', 'Yemen',
#        'Huila Colombia', 'southern', 'Uganda', 'Ethiopia; Guatemala',
#        'Brazil; Guatemala; Indonesia', 'Papua New Guinea; Guatemala',
#        'Indonesia; Ethiopia', 'Africa',
#        'Apaneca Ilamatepec mountain range', 'Guatemala; Ethiopia',
#        'Central America; South America; Ethiopia',
#        'Democratic Republic of Congo', 'Latin America',
#        'Americas; Indo-Pacific', 'Peru; Honduras; Mexico',
#        'northern Burundi', 'Hawaii', 'Big Island of Hawai‘i',
#        'Central America', 'East Malaysia', 'The Philippines',
#        'Nicaragua; Guatemala', 'Sumatra; Colombia', 'Zambia',
#        'Costa Rica; Sumatra', 'southwestern Tanzania',
#        'El Salvador; Costa Rica', 'Thailand', 'Peru; Ethiopia',
#        'El Salvador; Colombia; Ethiopia', 'northern Tanzania',
#        'El Salvador; Guatemala', 'Colombia; El Salvador; Ethiopia',
#        'Colombia; Ecuador; Indonesia; Uganda',
#        'Brazil; Ethiopia; Colombia', 'Guatemala; Brazil; Indonesia',
#        'Colombia; Brazil', 'Colombia; Brazil; Indonesia',
#        'Dominican Republic', 'Sumatra', 'central Kenya',
#        'south-central Guatemala', 'western Rwanda',
#        'Ethiopia; El Salvador', 'Central America; Africa',
#        'Brazil; Honduras; Yemen', 'Kenya; Ethiopia', 'Gedeo Zone',
#        'Papua New Guinea; Costa Rica',
#        'Ethiopia; Brazil; Guatemala; Colombia', 'Taiwan',
#        "“Big Island” of Hawai'i", 'south-Central Ethiopia',
#        'Africa; Central America', 'Brazil; Ethiopia; Costa Rica',
#        'Brazil; East Timor', "Big Island of Hawai'i",
#        'Africa; South America; Central America', 'South-central Kenya',
#        'Brazil; Guatemala; Sumatra', 'Haiti; Ethiopia',
#        'Papua New Guinea; Colombia', 'Ethiopia; Central America',
#        'Nicaragua; Guatemala; Ethiopia', 'northern Peru',
#        'South America; Central America; Africa',
#        'Ethiopia; Dominican Republic', 'southern Rwanda',
#        'southwestern Kenya', 'southwestern Ethiopia',
#        'Ethiopia; Colombia', 'Kenya; Guatemala', 'Kona; Panama; Mexico',
#        'Brazil; Ethiopia', 'Brazil; Guatemala', 'Madagascar',
#        '“Big Island” of Hawaii', 'southwestern Colombia',
#        'Guatemala; Colombia; Brazil',
#        'Ethiopia; Colombia; Guatemala; Brazil', 'Central Kenya',
#        'northern Guatemala', 'Big Island of Hawaii', 'DRC Congo',
#        'Colombia; Honduras; Rwanda', 'Nicaragua; East Timor',
#        'Nicaragua; Colombia; East Timor', 'Sumatra; Ethiopia', 'Hawai’i',
#        'Nepal',
#        'Brazil; Colombia; Rwanda; Democratic Republic of the Congo',
#        'Brazil; Costa Rica', 'El Salvador; Peru',
#        'Brazil; Colombia; Ethiopia', 'Central Rwanda',
#        'Ethiopia; Democratic Republic of the Congo',
#        'the Democratic Republic of the Congo',
#        'El Salvador; Ethiopia; Colombia', 'China', 'Ethiopia; Yemen',
#        'South Africa', 'western Kenya', '"Big Island" of Hawai’i',
#        'Ethiopia; Peru', 'Costa RIca', 'Big island of Hawai’i',
#        'far western Panama', 'Ethiopia; Rwanda; Colombia',
#        'Ethiopia; Kenya', 'southeastern Ethiopia', 'South America',
#        'Costa Rica; Ethiopia', 'west-central Bolivia', 'central Peru',
#        'north-central Ecuador', 'south-eastern Ecuador',
#        'north-central Peru', 'southern Ecuador',
#        'Harar (also Harrar) growing region of eastern Ethiopia',
#        'southeastern Brazil', 'west-central Colombia', 'Malaysia',
#        "Hawai'i", 'central Colombia', 'Central America; South America',
#        'Burundi; Colombia', 'Brazil; Ecuador',
#        'Central America; South America; Indonesia', 'Congo; Ethiopia',
#        'Ethiopia; Guatemala; Papua New Guinea; Sumatra',
#        'Eastern Highlands,Papua New Guinea', 'Zambia; Colombia',
#        'Africa; Asia', 'western Colombia', 'northwestern El Salvador',
#        'southeastern El Salvador', 'Asia; Africa; Americas', 'Jamaica',
#        'Sumatra; Panama; Kenya', 'Nicaragua; Ethiopia',
#        'Kenya; Ethiopia; Brazil', 'Ethiopia; Papua New Guinea; Guatemala',
#        'southern Costa Rica', 'Ethiopia; Costa Rica; Panama',
#        'Ethiopia; Kenya; Colombia', 'north-central Yemen',
#        'northern Thailand', 'Brazil and four other origins',
#        'central Guatemala', 'Kenya Gatugi AB', 'south-central Rwanda',
#        'Panama; Ethiopia', 'Guatemala; El Salvador; Ethiopia',
#        'Colombia; Kenya', 'El Salvador; Indonesia',
#        'center-west Colombia', 'Ethiopia; Burundi; Kenya',
#        'Northern Burundi', 'northern Ecuador', 'Ethopia; Rwanda; Peru',
#        'Ethiopia; Brazil', 'northwest El Salvador',
#        'Ethiopia; Central and South America',
#        'Ethiopia Natural Yirgacheffe Adado Shara',
#        'southwestern ColombiaNar', 'Central Yemen',
#        'Ethiopia; Colombia; Brazil', 'southwest Ethiopia',
#        'southwest Uganda', 'Africa; Indonesia; South America',
#        'central Costa Rica', 'western Uganda', 'Ethiopia; Honduras',
#        'western Ethiopia', 'Southern Province,Rwanda',
#        'Papua New Guinea; Burundi; Ethiopia; Kenya',
#        'Panama; Ethiopia; Burundi', 'eastern Ethiopia',
#        'Brazil; Costa Rica; Africa', 'Africa; the Pacific; South America',
#        'western El Salvador', 'north-central Nicaragua',
#        'Brazil; Kenya; Guatemala', 'central Puerto Rico',
#        'Mexico; Brazil', 'south-central KenyaMur',
#        'Central America; South America; East Africa',
#        'East Africa; Brazil', 'Colombia and Ethiopia', 'northern Rwanda',
#        'Africa; South and Central America', 'Southern India',
#        'northwestern Colombia',
#        'Colombia Aromas del Sur Palestina Micro-Lot', 'western Bolivia',
#        'Uganda or Congo; Ethiopia', 'Brazil; Nicaragua; Ethiopia',
#        'Zimbabwe', 'Brazil; Sumatra; El Salvador',
#        'Colombia; Congo; Ethiopia', 'Brazil; Ethiopia; Uganda',
#        'Brazil; Nicaragua; southern Ethiopia.', 'Myanmar',
#        'Colombia; Papua New Guinea; Zambia', 'Costa Rica.',
#        'southern Ethiopia.', 'Nicaragua; Peru; Tanzania.',
#        'northern Nicaragua.', '50% Colombia; 50% Ethiopia.', 'Indonesia.',
#        'south-central Kenya.', 'Rwanda.', 'Kenya; Panama; Ethiopia.',
#        'Kenya; Papua New Guinea.', 'South-central Kenya.', 'Nicaragua.',
#        'Central America.', 'western Panama.', 'south-central Ethiopia.',
#        'El Salvador; Kenya.', 'Central Kenya.', 'Colombia.', 'Kenya.',
#        'Not disclosed.', '“Big Island” of Hawaii.', 'Guatemala.',
#        'Honduras.', 'Brazil; Guatemala; Costa Rica.', 'central Kenya.',
#        'Western Rwanda.', 'Peru.', 'Burundi.', 'Papua New Guinea.',
#        'northern Burundi.', 'south-central Colombia.', 'Kenya; Ethiopia.',
#        'Ethiopia.', 'Bolivia.', 'southwestern Colombia.',
#        'far western Panama.', 'northern Rwanda.', 'central Colombia.',
#        'Brazil; Colombia; Ethiopia.',
#        '40% Colombia; 40% Brazil; 20% Rwanda.',
#        '50% Yirgacheffe Ethiopia; 25% Papua New Guinea; 25% Brazil.',
#        'Guatemala; West Java; Colombia.', 'Costa Rica; Ethiopia; Brazil.',
#        '15% Sumatra.', 'Panama.', 'Democratic Republic of the Congo.',
#        'southern Colombia.', 'Tanzania.', 'Kenya; Brazil.', 'Mexico.',
#        'southwest Ethiopia.', 'Brazil.', 'El Salvador.',
#        'Southern Ethiopia; Central America.', 'East and Central Africa.',
#        'Brazil; Guatemala; other Central America origins.',
#        'Various Latin American origins.', 'southwestern Mexico.',
#        'Ethiopia; Brazil; Indonesia.', 'Brazil; Ethiopia; Costa Rica.',
#        'Burundi; Brazil; Colombia.', 'Big Island of Hawaii.',
#        'southwestern Kenya.',
#        'Guatemala; Colombia; Costa Rica; Ethiopia; Kenya.',
#        'eastern Jamaica.', 'western Guatemala.', 'eastern Zimbabwe.',
#        'southern and western Ethiopia', 'Guatemala; Indonesia; Mexico',
#        'southern Laos', 'Indonesia; Papua New Guinea',
#        'Colombia; Ethiopia.', 'Honduras; Kenya; Ethiopia',
#        'Guatemala; Ethiopia.', 'Ethiopia; Kenya.', 'souther Ethiopia.',
#        'Brazil; Guatemala; Ethiopia.', 'southern Ethiopia; Uganda.',
#        'Brazil; Ethiopia; El Salvador.', 'Brazil; Kenya; Tanzania.',
#        'souther Ecuador.', 'Ecuador.', 'east-central Brazil.',
#        'south-central Brazil.',
#        'South America; Central America; Indonesia.', 'Mexico; Ethiopia.',
#        'Eastern Java; Indonesia.', 'west-central Colombia.',
#        'western Rwanda.', 'southwestern Tanzania.', 'southern Tanzania.',
#        'Southern Peru', 'Eastern Papua New Guinea.',
#        'southeastern Mexico.', 'Western Guatemala', 'western Kenya.',
#        'South America; Africa.', 'central northwest Colombia.',
#        'Southern Ethiopia.', 'Hawaii.', '"Big Island" of Hawaii.',
#        'Hawaiian Islands.', 'central Costa Rica.', 'central Honduras.',
#        'central Guatemala.', 'north-central Nicaragua.',
#        'southern Rwanda.', 'south-central Guatemala.',
#        'Northern Thailand.', 'Indonesia; Central America.',
#        'southern Ecuador.', 'USA.', 'Kenya; Guatemala.',
#        'Northern Rwanda', 'south-central Colombia', 'western Ethiopia.',
#        'Brazil; Central America; Sumatra.', 'southern Costa Rica.',
#        '"Big Island" of Hawaii', 'southeastern Peru.',
#        'west-central Bolivia.', 'western highlands of Papua New Guinea.',
#        'Southern Malawi.', 'north-central Guatemala.',
#        'south central Guatemala', 'Highlands of Papua New Guinea',
#        'northern Sumatra.', 'Central Costa Rica', 'southeastern Brazil.',
#        'Big Island of Hawaii; other undisclosed origins.', 'Haiti.',
#        'central Papua New Guinea.', 'South-Central Brazil',
#        'Asia and Latin America.', 'Latin America; East Africa.',
#        'Peru; Ecuador', 'Africa; the Americas; Indonesia',
#        'Latin America; Indonesia.', 'Latin America.', 'central Rwanda.',
#        'Indonesia; Mexico.', 'Brazil; Mexico.', 'northwestern Guatemala.',
#        'Western Ethiopia', 'Southern Ethiopia; Indonesia.',
#        'western Uganda.', 'Western El Salvador', 'Nicaragua; Guatemala.',
#        'Africa; South America.', 'southwestern Ethiopia.',
#        'southwestern Guatemala', 'Indonesia; Honduras; Ethiopia.',
#        'Central America; Indonesia; East Africa.', 'Java; Kenya.',
#        'El Salvador; Sulawesi.', 'Indonesia; southern Ethiopia.',
#        'Philippines.', 'Minas Gerais State.',
#        'central northwest Colombia', 'Panama; Brazil.',
#        'Ethiopia; Tanzania.', 'Eastern Java.', 'northern Tanzania.',
#        'Sumatra.', 'southeastern Mexico', 'Indonesia and Costa Rica.',
#        'Northwest El Salvador.', 'Central and South America.',
#        'Northwestern El Salvador', 'Southern Honduras.',
#        'Sumatra; Ethiopia; Guatemala.', 'Indonesia and Central America',
#        'Guatemala.e', 'East Africa.', 'Colombia; El Salvador; Panama.',
#        'southwestern corner of the "Big Island" of Hawaii.',
#        'southwestern Guatemala.', 'southern India.',
#        'southern Ethiopia; eastern Java.', 'Central Zambia',
#        'Kenya; Colombia; Brazil', 'South America; East Africa',
#        'Brazil; Colombia', 'Brazil; Mexico', 'Americas; Indonesia',
#        'El Salvador; Ethiopia.', 'Ethiopia; Rwanda; Guatemala.',
#        'Honduras; Ethiopia.', 'Costa Rica; Brazil.',
#        'northeastern Ethiopia.', 'Hawaii; Sumatra; Ethiopia'],
#       dtype=object)

# %%
# I'll start with stripping any whitespace and putting everything in title case.
coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.strip().str.title()
coffee_origins['coffee_origin'].unique()
# Out:
# array(['Bolivia', 'Ethiopia', 'Southern Ethiopia', 'Colombia',
#        'Guatemala', 'Papua New Guinea', 'Northern Philippines',
#        'Big Island Of Hawai’I', 'Brazil', 'Peru', 'Ethiopia; Sumatra',
#        'El Salvador', 'Tanzania', 'Kenya', 'Panama',
#        'Democratic Republic Of The Congo', 'Costa Rica', 'Ecuador',
#        'Southwest Vietnam', 'Indonesia', 'Central El Salvador',
#        'Nicaragua', '“Big Island” Of Hawai’I', 'Mexico', 'Rwanda',
#        'Haiti', 'Dominican Republic; Honduras', 'Vietnam',
#        'Thailand; Vietnam; Latin America', 'Not Disclosed',
#        'South-Central Kenya', 'Northern Nicaragua', 'Burundi',
#        'Guatemala; Nicaragua; Ethiopia; Costa Rica; Indonesia; Brazil',
#        'Colombia; Ethiopia', 'Honduras', 'Colombia; Guatemala; Mexico',
#        'Guatemala; Ethiopia; Colombia', 'South-Central Ethiopia',
#        'Western Panama', 'Philippines', 'Southern Colombia',
#        'Colombia; Guatemala; Costa Rica; Ethiopia', 'Yemen',
#        'Huila Colombia', 'Southern', 'Uganda', 'Ethiopia; Guatemala',
#        'Brazil; Guatemala; Indonesia', 'Papua New Guinea; Guatemala',
#        'Indonesia; Ethiopia', 'Africa',
#        'Apaneca Ilamatepec Mountain Range', 'Guatemala; Ethiopia',
#        'Central America; South America; Ethiopia',
#        'Democratic Republic Of Congo', 'Latin America',
#        'Americas; Indo-Pacific', 'Peru; Honduras; Mexico',
#        'Northern Burundi', 'Hawaii', 'Big Island Of Hawai‘I',
#        'Central America', 'East Malaysia', 'The Philippines',
#        'Nicaragua; Guatemala', 'Sumatra; Colombia', 'Zambia',
#        'Costa Rica; Sumatra', 'Southwestern Tanzania',
#        'El Salvador; Costa Rica', 'Thailand', 'Peru; Ethiopia',
#        'El Salvador; Colombia; Ethiopia', 'Northern Tanzania',
#        'El Salvador; Guatemala', 'Colombia; El Salvador; Ethiopia',
#        'Colombia; Ecuador; Indonesia; Uganda',
#        'Brazil; Ethiopia; Colombia', 'Guatemala; Brazil; Indonesia',
#        'Colombia; Brazil', 'Colombia; Brazil; Indonesia',
#        'Dominican Republic', 'Sumatra', 'Central Kenya',
#        'South-Central Guatemala', 'Western Rwanda',
#        'Ethiopia; El Salvador', 'Central America; Africa',
#        'Brazil; Honduras; Yemen', 'Kenya; Ethiopia', 'Gedeo Zone',
#        'Papua New Guinea; Costa Rica',
#        'Ethiopia; Brazil; Guatemala; Colombia', 'Taiwan',
#        "“Big Island” Of Hawai'I", 'Africa; Central America',
#        'Brazil; Ethiopia; Costa Rica', 'Brazil; East Timor',
#        "Big Island Of Hawai'I", 'Africa; South America; Central America',
#        'Brazil; Guatemala; Sumatra', 'Haiti; Ethiopia',
#        'Papua New Guinea; Colombia', 'Ethiopia; Central America',
#        'Nicaragua; Guatemala; Ethiopia', 'Northern Peru',
#        'South America; Central America; Africa',
#        'Ethiopia; Dominican Republic', 'Southern Rwanda',
#        'Southwestern Kenya', 'Southwestern Ethiopia',
#        'Ethiopia; Colombia', 'Kenya; Guatemala', 'Kona; Panama; Mexico',
#        'Brazil; Ethiopia', 'Brazil; Guatemala', 'Madagascar',
#        '“Big Island” Of Hawaii', 'Southwestern Colombia',
#        'Guatemala; Colombia; Brazil',
#        'Ethiopia; Colombia; Guatemala; Brazil', 'Northern Guatemala',
#        'Big Island Of Hawaii', 'Drc Congo', 'Colombia; Honduras; Rwanda',
#        'Nicaragua; East Timor', 'Nicaragua; Colombia; East Timor',
#        'Sumatra; Ethiopia', 'Hawai’I', 'Nepal',
#        'Brazil; Colombia; Rwanda; Democratic Republic Of The Congo',
#        'Brazil; Costa Rica', 'El Salvador; Peru',
#        'Brazil; Colombia; Ethiopia', 'Central Rwanda',
#        'Ethiopia; Democratic Republic Of The Congo',
#        'The Democratic Republic Of The Congo',
#        'El Salvador; Ethiopia; Colombia', 'China', 'Ethiopia; Yemen',
#        'South Africa', 'Western Kenya', '"Big Island" Of Hawai’I',
#        'Ethiopia; Peru', 'Far Western Panama',
#        'Ethiopia; Rwanda; Colombia', 'Ethiopia; Kenya',
#        'Southeastern Ethiopia', 'South America', 'Costa Rica; Ethiopia',
#        'West-Central Bolivia', 'Central Peru', 'North-Central Ecuador',
#        'South-Eastern Ecuador', 'North-Central Peru', 'Southern Ecuador',
#        'Harar (Also Harrar) Growing Region Of Eastern Ethiopia',
#        'Southeastern Brazil', 'West-Central Colombia', 'Malaysia',
#        "Hawai'I", 'Central Colombia', 'Central America; South America',
#        'Burundi; Colombia', 'Brazil; Ecuador',
#        'Central America; South America; Indonesia', 'Congo; Ethiopia',
#        'Ethiopia; Guatemala; Papua New Guinea; Sumatra',
#        'Eastern Highlands,Papua New Guinea', 'Zambia; Colombia',
#        'Africa; Asia', 'Western Colombia', 'Northwestern El Salvador',
#        'Southeastern El Salvador', 'Asia; Africa; Americas', 'Jamaica',
#        'Sumatra; Panama; Kenya', 'Nicaragua; Ethiopia',
#        'Kenya; Ethiopia; Brazil', 'Ethiopia; Papua New Guinea; Guatemala',
#        'Southern Costa Rica', 'Ethiopia; Costa Rica; Panama',
#        'Ethiopia; Kenya; Colombia', 'North-Central Yemen',
#        'Northern Thailand', 'Brazil And Four Other Origins',
#        'Central Guatemala', 'Kenya Gatugi Ab', 'South-Central Rwanda',
#        'Panama; Ethiopia', 'Guatemala; El Salvador; Ethiopia',
#        'Colombia; Kenya', 'El Salvador; Indonesia',
#        'Center-West Colombia', 'Ethiopia; Burundi; Kenya',
#        'Northern Ecuador', 'Ethopia; Rwanda; Peru', 'Ethiopia; Brazil',
#        'Northwest El Salvador', 'Ethiopia; Central And South America',
#        'Ethiopia Natural Yirgacheffe Adado Shara',
#        'Southwestern Colombianar', 'Central Yemen',
#        'Ethiopia; Colombia; Brazil', 'Southwest Ethiopia',
#        'Southwest Uganda', 'Africa; Indonesia; South America',
#        'Central Costa Rica', 'Western Uganda', 'Ethiopia; Honduras',
#        'Western Ethiopia', 'Southern Province,Rwanda',
#        'Papua New Guinea; Burundi; Ethiopia; Kenya',
#        'Panama; Ethiopia; Burundi', 'Eastern Ethiopia',
#        'Brazil; Costa Rica; Africa', 'Africa; The Pacific; South America',
#        'Western El Salvador', 'North-Central Nicaragua',
#        'Brazil; Kenya; Guatemala', 'Central Puerto Rico',
#        'Mexico; Brazil', 'South-Central Kenyamur',
#        'Central America; South America; East Africa',
#        'East Africa; Brazil', 'Colombia And Ethiopia', 'Northern Rwanda',
#        'Africa; South And Central America', 'Southern India',
#        'Northwestern Colombia',
#        'Colombia Aromas Del Sur Palestina Micro-Lot', 'Western Bolivia',
#        'Uganda Or Congo; Ethiopia', 'Brazil; Nicaragua; Ethiopia',
#        'Zimbabwe', 'Brazil; Sumatra; El Salvador',
#        'Colombia; Congo; Ethiopia', 'Brazil; Ethiopia; Uganda',
#        'Brazil; Nicaragua; Southern Ethiopia.', 'Myanmar',
#        'Colombia; Papua New Guinea; Zambia', 'Costa Rica.',
#        'Southern Ethiopia.', 'Nicaragua; Peru; Tanzania.',
#        'Northern Nicaragua.', '50% Colombia; 50% Ethiopia.', 'Indonesia.',
#        'South-Central Kenya.', 'Rwanda.', 'Kenya; Panama; Ethiopia.',
#        'Kenya; Papua New Guinea.', 'Nicaragua.', 'Central America.',
#        'Western Panama.', 'South-Central Ethiopia.',
#        'El Salvador; Kenya.', 'Central Kenya.', 'Colombia.', 'Kenya.',
#        'Not Disclosed.', '“Big Island” Of Hawaii.', 'Guatemala.',
#        'Honduras.', 'Brazil; Guatemala; Costa Rica.', 'Western Rwanda.',
#        'Peru.', 'Burundi.', 'Papua New Guinea.', 'Northern Burundi.',
#        'South-Central Colombia.', 'Kenya; Ethiopia.', 'Ethiopia.',
#        'Bolivia.', 'Southwestern Colombia.', 'Far Western Panama.',
#        'Northern Rwanda.', 'Central Colombia.',
#        'Brazil; Colombia; Ethiopia.',
#        '40% Colombia; 40% Brazil; 20% Rwanda.',
#        '50% Yirgacheffe Ethiopia; 25% Papua New Guinea; 25% Brazil.',
#        'Guatemala; West Java; Colombia.', 'Costa Rica; Ethiopia; Brazil.',
#        '15% Sumatra.', 'Panama.', 'Democratic Republic Of The Congo.',
#        'Southern Colombia.', 'Tanzania.', 'Kenya; Brazil.', 'Mexico.',
#        'Southwest Ethiopia.', 'Brazil.', 'El Salvador.',
#        'Southern Ethiopia; Central America.', 'East And Central Africa.',
#        'Brazil; Guatemala; Other Central America Origins.',
#        'Various Latin American Origins.', 'Southwestern Mexico.',
#        'Ethiopia; Brazil; Indonesia.', 'Brazil; Ethiopia; Costa Rica.',
#        'Burundi; Brazil; Colombia.', 'Big Island Of Hawaii.',
#        'Southwestern Kenya.',
#        'Guatemala; Colombia; Costa Rica; Ethiopia; Kenya.',
#        'Eastern Jamaica.', 'Western Guatemala.', 'Eastern Zimbabwe.',
#        'Southern And Western Ethiopia', 'Guatemala; Indonesia; Mexico',
#        'Southern Laos', 'Indonesia; Papua New Guinea',
#        'Colombia; Ethiopia.', 'Honduras; Kenya; Ethiopia',
#        'Guatemala; Ethiopia.', 'Ethiopia; Kenya.', 'Souther Ethiopia.',
#        'Brazil; Guatemala; Ethiopia.', 'Southern Ethiopia; Uganda.',
#        'Brazil; Ethiopia; El Salvador.', 'Brazil; Kenya; Tanzania.',
#        'Souther Ecuador.', 'Ecuador.', 'East-Central Brazil.',
#        'South-Central Brazil.',
#        'South America; Central America; Indonesia.', 'Mexico; Ethiopia.',
#        'Eastern Java; Indonesia.', 'West-Central Colombia.',
#        'Southwestern Tanzania.', 'Southern Tanzania.', 'Southern Peru',
#        'Eastern Papua New Guinea.', 'Southeastern Mexico.',
#        'Western Guatemala', 'Western Kenya.', 'South America; Africa.',
#        'Central Northwest Colombia.', 'Hawaii.',
#        '"Big Island" Of Hawaii.', 'Hawaiian Islands.',
#        'Central Costa Rica.', 'Central Honduras.', 'Central Guatemala.',
#        'North-Central Nicaragua.', 'Southern Rwanda.',
#        'South-Central Guatemala.', 'Northern Thailand.',
#        'Indonesia; Central America.', 'Southern Ecuador.', 'Usa.',
#        'Kenya; Guatemala.', 'South-Central Colombia', 'Western Ethiopia.',
#        'Brazil; Central America; Sumatra.', 'Southern Costa Rica.',
#        '"Big Island" Of Hawaii', 'Southeastern Peru.',
#        'West-Central Bolivia.', 'Western Highlands Of Papua New Guinea.',
#        'Southern Malawi.', 'North-Central Guatemala.',
#        'South Central Guatemala', 'Highlands Of Papua New Guinea',
#        'Northern Sumatra.', 'Southeastern Brazil.',
#        'Big Island Of Hawaii; Other Undisclosed Origins.', 'Haiti.',
#        'Central Papua New Guinea.', 'South-Central Brazil',
#        'Asia And Latin America.', 'Latin America; East Africa.',
#        'Peru; Ecuador', 'Africa; The Americas; Indonesia',
#        'Latin America; Indonesia.', 'Latin America.', 'Central Rwanda.',
#        'Indonesia; Mexico.', 'Brazil; Mexico.', 'Northwestern Guatemala.',
#        'Southern Ethiopia; Indonesia.', 'Western Uganda.',
#        'Nicaragua; Guatemala.', 'Africa; South America.',
#        'Southwestern Ethiopia.', 'Southwestern Guatemala',
#        'Indonesia; Honduras; Ethiopia.',
#        'Central America; Indonesia; East Africa.', 'Java; Kenya.',
#        'El Salvador; Sulawesi.', 'Indonesia; Southern Ethiopia.',
#        'Philippines.', 'Minas Gerais State.',
#        'Central Northwest Colombia', 'Panama; Brazil.',
#        'Ethiopia; Tanzania.', 'Eastern Java.', 'Northern Tanzania.',
#        'Sumatra.', 'Southeastern Mexico', 'Indonesia And Costa Rica.',
#        'Northwest El Salvador.', 'Central And South America.',
#        'Southern Honduras.', 'Sumatra; Ethiopia; Guatemala.',
#        'Indonesia And Central America', 'Guatemala.E', 'East Africa.',
#        'Colombia; El Salvador; Panama.',
#        'Southwestern Corner Of The "Big Island" Of Hawaii.',
#        'Southwestern Guatemala.', 'Southern India.',
#        'Southern Ethiopia; Eastern Java.', 'Central Zambia',
#        'Kenya; Colombia; Brazil', 'South America; East Africa',
#        'Brazil; Colombia', 'Brazil; Mexico', 'Americas; Indonesia',
#        'El Salvador; Ethiopia.', 'Ethiopia; Rwanda; Guatemala.',
#        'Honduras; Ethiopia.', 'Costa Rica; Brazil.',
#        'Northeastern Ethiopia.', 'Hawaii; Sumatra; Ethiopia'],
#       dtype=object)

# %%
# It looks like many of these are blends of beans from several different regions, separated
# by a ';'. I'm not going to include those in my analysis, so I'll filter them out.
coffee_origins = coffee_origins[~(coffee_origins['coffee_origin'].str.contains(';', na=False))]
coffee_origins['coffee_origin'].unique()
# Out:
# array(['Bolivia', 'Ethiopia', 'Southern Ethiopia', 'Colombia',
#        'Guatemala', 'Papua New Guinea', 'Northern Philippines',
#        'Big Island Of Hawai’I', 'Brazil', 'Peru', 'El Salvador',
#        'Tanzania', 'Kenya', 'Panama', 'Democratic Republic Of The Congo',
#        'Costa Rica', 'Ecuador', 'Southwest Vietnam', 'Indonesia',
#        'Central El Salvador', 'Nicaragua', '“Big Island” Of Hawai’I',
#        'Mexico', 'Rwanda', 'Haiti', 'Vietnam', 'Not Disclosed',
#        'South-Central Kenya', 'Northern Nicaragua', 'Burundi', 'Honduras',
#        'South-Central Ethiopia', 'Western Panama', 'Philippines',
#        'Southern Colombia', 'Yemen', 'Huila Colombia', 'Southern',
#        'Uganda', 'Africa', 'Apaneca Ilamatepec Mountain Range',
#        'Democratic Republic Of Congo', 'Latin America',
#        'Northern Burundi', 'Hawaii', 'Big Island Of Hawai‘I',
#        'Central America', 'East Malaysia', 'The Philippines', 'Zambia',
#        'Southwestern Tanzania', 'Thailand', 'Northern Tanzania',
#        'Dominican Republic', 'Sumatra', 'Central Kenya',
#        'South-Central Guatemala', 'Western Rwanda', 'Gedeo Zone',
#        'Taiwan', "“Big Island” Of Hawai'I", "Big Island Of Hawai'I",
#        'Northern Peru', 'Southern Rwanda', 'Southwestern Kenya',
#        'Southwestern Ethiopia', 'Madagascar', '“Big Island” Of Hawaii',
#        'Southwestern Colombia', 'Northern Guatemala',
#        'Big Island Of Hawaii', 'Drc Congo', 'Hawai’I', 'Nepal',
#        'Central Rwanda', 'The Democratic Republic Of The Congo', 'China',
#        'South Africa', 'Western Kenya', '"Big Island" Of Hawai’I',
#        'Far Western Panama', 'Southeastern Ethiopia', 'South America',
#        'West-Central Bolivia', 'Central Peru', 'North-Central Ecuador',
#        'South-Eastern Ecuador', 'North-Central Peru', 'Southern Ecuador',
#        'Harar (Also Harrar) Growing Region Of Eastern Ethiopia',
#        'Southeastern Brazil', 'West-Central Colombia', 'Malaysia',
#        "Hawai'I", 'Central Colombia',
#        'Eastern Highlands,Papua New Guinea', 'Western Colombia',
#        'Northwestern El Salvador', 'Southeastern El Salvador', 'Jamaica',
#        'Southern Costa Rica', 'North-Central Yemen', 'Northern Thailand',
#        'Brazil And Four Other Origins', 'Central Guatemala',
#        'Kenya Gatugi Ab', 'South-Central Rwanda', 'Center-West Colombia',
#        'Northern Ecuador', 'Northwest El Salvador',
#        'Ethiopia Natural Yirgacheffe Adado Shara',
#        'Southwestern Colombianar', 'Central Yemen', 'Southwest Ethiopia',
#        'Southwest Uganda', 'Central Costa Rica', 'Western Uganda',
#        'Western Ethiopia', 'Southern Province,Rwanda', 'Eastern Ethiopia',
#        'Western El Salvador', 'North-Central Nicaragua',
#        'Central Puerto Rico', 'South-Central Kenyamur',
#        'Colombia And Ethiopia', 'Northern Rwanda', 'Southern India',
#        'Northwestern Colombia',
#        'Colombia Aromas Del Sur Palestina Micro-Lot', 'Western Bolivia',
#        'Zimbabwe', 'Myanmar', 'Costa Rica.', 'Southern Ethiopia.',
#        'Northern Nicaragua.', 'Indonesia.', 'South-Central Kenya.',
#        'Rwanda.', 'Nicaragua.', 'Central America.', 'Western Panama.',
#        'South-Central Ethiopia.', 'Central Kenya.', 'Colombia.', 'Kenya.',
#        'Not Disclosed.', '“Big Island” Of Hawaii.', 'Guatemala.',
#        'Honduras.', 'Western Rwanda.', 'Peru.', 'Burundi.',
#        'Papua New Guinea.', 'Northern Burundi.',
#        'South-Central Colombia.', 'Ethiopia.', 'Bolivia.',
#        'Southwestern Colombia.', 'Far Western Panama.',
#        'Northern Rwanda.', 'Central Colombia.', '15% Sumatra.', 'Panama.',
#        'Democratic Republic Of The Congo.', 'Southern Colombia.',
#        'Tanzania.', 'Mexico.', 'Southwest Ethiopia.', 'Brazil.',
#        'El Salvador.', 'East And Central Africa.',
#        'Various Latin American Origins.', 'Southwestern Mexico.',
#        'Big Island Of Hawaii.', 'Southwestern Kenya.', 'Eastern Jamaica.',
#        'Western Guatemala.', 'Eastern Zimbabwe.',
#        'Southern And Western Ethiopia', 'Southern Laos',
#        'Souther Ethiopia.', 'Souther Ecuador.', 'Ecuador.',
#        'East-Central Brazil.', 'South-Central Brazil.',
#        'West-Central Colombia.', 'Southwestern Tanzania.',
#        'Southern Tanzania.', 'Southern Peru', 'Eastern Papua New Guinea.',
#        'Southeastern Mexico.', 'Western Guatemala', 'Western Kenya.',
#        'Central Northwest Colombia.', 'Hawaii.',
#        '"Big Island" Of Hawaii.', 'Hawaiian Islands.',
#        'Central Costa Rica.', 'Central Honduras.', 'Central Guatemala.',
#        'North-Central Nicaragua.', 'Southern Rwanda.',
#        'South-Central Guatemala.', 'Northern Thailand.',
#        'Southern Ecuador.', 'Usa.', 'South-Central Colombia',
#        'Western Ethiopia.', 'Southern Costa Rica.',
#        '"Big Island" Of Hawaii', 'Southeastern Peru.',
#        'West-Central Bolivia.', 'Western Highlands Of Papua New Guinea.',
#        'Southern Malawi.', 'North-Central Guatemala.',
#        'South Central Guatemala', 'Highlands Of Papua New Guinea',
#        'Northern Sumatra.', 'Southeastern Brazil.', 'Haiti.',
#        'Central Papua New Guinea.', 'South-Central Brazil',
#        'Asia And Latin America.', 'Latin America.', 'Central Rwanda.',
#        'Northwestern Guatemala.', 'Western Uganda.',
#        'Southwestern Ethiopia.', 'Southwestern Guatemala', 'Philippines.',
#        'Minas Gerais State.', 'Central Northwest Colombia',
#        'Eastern Java.', 'Northern Tanzania.', 'Sumatra.',
#        'Southeastern Mexico', 'Indonesia And Costa Rica.',
#        'Northwest El Salvador.', 'Central And South America.',
#        'Southern Honduras.', 'Indonesia And Central America',
#        'Guatemala.E', 'East Africa.',
#        'Southwestern Corner Of The "Big Island" Of Hawaii.',
#        'Southwestern Guatemala.', 'Southern India.', 'Central Zambia',
#        'Northeastern Ethiopia.'], dtype=object)

# %%
# Many of them have a trailing '.'
coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace('.', '')
coffee_origins['coffee_origin'].unique()
# Out:
# C:\Users\samia\AppData\Local\Temp\ipykernel_10744\1665217202.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace('.', '')
# array(['Bolivia', 'Ethiopia', 'Southern Ethiopia', 'Colombia',
#        'Guatemala', 'Papua New Guinea', 'Northern Philippines',
#        'Big Island Of Hawai’I', 'Brazil', 'Peru', 'El Salvador',
#        'Tanzania', 'Kenya', 'Panama', 'Democratic Republic Of The Congo',
#        'Costa Rica', 'Ecuador', 'Southwest Vietnam', 'Indonesia',
#        'Central El Salvador', 'Nicaragua', '“Big Island” Of Hawai’I',
#        'Mexico', 'Rwanda', 'Haiti', 'Vietnam', 'Not Disclosed',
#        'South-Central Kenya', 'Northern Nicaragua', 'Burundi', 'Honduras',
#        'South-Central Ethiopia', 'Western Panama', 'Philippines',
#        'Southern Colombia', 'Yemen', 'Huila Colombia', 'Southern',
#        'Uganda', 'Africa', 'Apaneca Ilamatepec Mountain Range',
#        'Democratic Republic Of Congo', 'Latin America',
#        'Northern Burundi', 'Hawaii', 'Big Island Of Hawai‘I',
#        'Central America', 'East Malaysia', 'The Philippines', 'Zambia',
#        'Southwestern Tanzania', 'Thailand', 'Northern Tanzania',
#        'Dominican Republic', 'Sumatra', 'Central Kenya',
#        'South-Central Guatemala', 'Western Rwanda', 'Gedeo Zone',
#        'Taiwan', "“Big Island” Of Hawai'I", "Big Island Of Hawai'I",
#        'Northern Peru', 'Southern Rwanda', 'Southwestern Kenya',
#        'Southwestern Ethiopia', 'Madagascar', '“Big Island” Of Hawaii',
#        'Southwestern Colombia', 'Northern Guatemala',
#        'Big Island Of Hawaii', 'Drc Congo', 'Hawai’I', 'Nepal',
#        'Central Rwanda', 'The Democratic Republic Of The Congo', 'China',
#        'South Africa', 'Western Kenya', '"Big Island" Of Hawai’I',
#        'Far Western Panama', 'Southeastern Ethiopia', 'South America',
#        'West-Central Bolivia', 'Central Peru', 'North-Central Ecuador',
#        'South-Eastern Ecuador', 'North-Central Peru', 'Southern Ecuador',
#        'Harar (Also Harrar) Growing Region Of Eastern Ethiopia',
#        'Southeastern Brazil', 'West-Central Colombia', 'Malaysia',
#        "Hawai'I", 'Central Colombia',
#        'Eastern Highlands,Papua New Guinea', 'Western Colombia',
#        'Northwestern El Salvador', 'Southeastern El Salvador', 'Jamaica',
#        'Southern Costa Rica', 'North-Central Yemen', 'Northern Thailand',
#        'Brazil And Four Other Origins', 'Central Guatemala',
#        'Kenya Gatugi Ab', 'South-Central Rwanda', 'Center-West Colombia',
#        'Northern Ecuador', 'Northwest El Salvador',
#        'Ethiopia Natural Yirgacheffe Adado Shara',
#        'Southwestern Colombianar', 'Central Yemen', 'Southwest Ethiopia',
#        'Southwest Uganda', 'Central Costa Rica', 'Western Uganda',
#        'Western Ethiopia', 'Southern Province,Rwanda', 'Eastern Ethiopia',
#        'Western El Salvador', 'North-Central Nicaragua',
#        'Central Puerto Rico', 'South-Central Kenyamur',
#        'Colombia And Ethiopia', 'Northern Rwanda', 'Southern India',
#        'Northwestern Colombia',
#        'Colombia Aromas Del Sur Palestina Micro-Lot', 'Western Bolivia',
#        'Zimbabwe', 'Myanmar', 'South-Central Colombia', '15% Sumatra',
#        'East And Central Africa', 'Various Latin American Origins',
#        'Southwestern Mexico', 'Eastern Jamaica', 'Western Guatemala',
#        'Eastern Zimbabwe', 'Southern And Western Ethiopia',
#        'Southern Laos', 'Souther Ethiopia', 'Souther Ecuador',
#        'East-Central Brazil', 'South-Central Brazil', 'Southern Tanzania',
#        'Southern Peru', 'Eastern Papua New Guinea', 'Southeastern Mexico',
#        'Central Northwest Colombia', '"Big Island" Of Hawaii',
#        'Hawaiian Islands', 'Central Honduras', 'Usa', 'Southeastern Peru',
#        'Western Highlands Of Papua New Guinea', 'Southern Malawi',
#        'North-Central Guatemala', 'South Central Guatemala',
#        'Highlands Of Papua New Guinea', 'Northern Sumatra',
#        'Central Papua New Guinea', 'Asia And Latin America',
#        'Northwestern Guatemala', 'Southwestern Guatemala',
#        'Minas Gerais State', 'Eastern Java', 'Indonesia And Costa Rica',
#        'Central And South America', 'Southern Honduras',
#        'Indonesia And Central America', 'GuatemalaE', 'East Africa',
#        'Southwestern Corner Of The "Big Island" Of Hawaii',
#        'Central Zambia', 'Northeastern Ethiopia'], dtype=object)

# %%
# Lots of these are hawaii...
coffee_hawaii = coffee_origins.loc[coffee_origins['coffee_origin'].str.contains('Hawai', na=False)]
coffee_hawaii['coffee_origin'].unique().tolist()
# Out:
# ['Big Island Of Hawai’I',
#  '“Big Island” Of Hawai’I',
#  'Hawaii',
#  'Big Island Of Hawai‘I',
#  "“Big Island” Of Hawai'I",
#  "Big Island Of Hawai'I",
#  '“Big Island” Of Hawaii',
#  'Big Island Of Hawaii',
#  'Hawai’I',
#  '"Big Island" Of Hawai’I',
#  "Hawai'I",
#  '"Big Island" Of Hawaii',
#  'Hawaiian Islands',
#  'Southwestern Corner Of The "Big Island" Of Hawaii']

# %%
coffee_origins = coffee_origins[~(coffee_origins['coffee_origin'].str.contains('Hawai', na=False))]
coffee_origins['coffee_origin'].unique()
# Great! We're getting to the point now where I should start removing the 'Southern's and 'West-Central's and all of that.
# Out:
# array(['Bolivia', 'Ethiopia', 'Southern Ethiopia', 'Colombia',
#        'Guatemala', 'Papua New Guinea', 'Northern Philippines', 'Brazil',
#        'Peru', 'El Salvador', 'Tanzania', 'Kenya', 'Panama',
#        'Democratic Republic Of The Congo', 'Costa Rica', 'Ecuador',
#        'Southwest Vietnam', 'Indonesia', 'Central El Salvador',
#        'Nicaragua', 'Mexico', 'Rwanda', 'Haiti', 'Vietnam',
#        'Not Disclosed', 'South-Central Kenya', 'Northern Nicaragua',
#        'Burundi', 'Honduras', 'South-Central Ethiopia', 'Western Panama',
#        'Philippines', 'Southern Colombia', 'Yemen', 'Huila Colombia',
#        'Southern', 'Uganda', 'Africa',
#        'Apaneca Ilamatepec Mountain Range',
#        'Democratic Republic Of Congo', 'Latin America',
#        'Northern Burundi', 'Central America', 'East Malaysia',
#        'The Philippines', 'Zambia', 'Southwestern Tanzania', 'Thailand',
#        'Northern Tanzania', 'Dominican Republic', 'Sumatra',
#        'Central Kenya', 'South-Central Guatemala', 'Western Rwanda',
#        'Gedeo Zone', 'Taiwan', 'Northern Peru', 'Southern Rwanda',
#        'Southwestern Kenya', 'Southwestern Ethiopia', 'Madagascar',
#        'Southwestern Colombia', 'Northern Guatemala', 'Drc Congo',
#        'Nepal', 'Central Rwanda', 'The Democratic Republic Of The Congo',
#        'China', 'South Africa', 'Western Kenya', 'Far Western Panama',
#        'Southeastern Ethiopia', 'South America', 'West-Central Bolivia',
#        'Central Peru', 'North-Central Ecuador', 'South-Eastern Ecuador',
#        'North-Central Peru', 'Southern Ecuador',
#        'Harar (Also Harrar) Growing Region Of Eastern Ethiopia',
#        'Southeastern Brazil', 'West-Central Colombia', 'Malaysia',
#        'Central Colombia', 'Eastern Highlands,Papua New Guinea',
#        'Western Colombia', 'Northwestern El Salvador',
#        'Southeastern El Salvador', 'Jamaica', 'Southern Costa Rica',
#        'North-Central Yemen', 'Northern Thailand',
#        'Brazil And Four Other Origins', 'Central Guatemala',
#        'Kenya Gatugi Ab', 'South-Central Rwanda', 'Center-West Colombia',
#        'Northern Ecuador', 'Northwest El Salvador',
#        'Ethiopia Natural Yirgacheffe Adado Shara',
#        'Southwestern Colombianar', 'Central Yemen', 'Southwest Ethiopia',
#        'Southwest Uganda', 'Central Costa Rica', 'Western Uganda',
#        'Western Ethiopia', 'Southern Province,Rwanda', 'Eastern Ethiopia',
#        'Western El Salvador', 'North-Central Nicaragua',
#        'Central Puerto Rico', 'South-Central Kenyamur',
#        'Colombia And Ethiopia', 'Northern Rwanda', 'Southern India',
#        'Northwestern Colombia',
#        'Colombia Aromas Del Sur Palestina Micro-Lot', 'Western Bolivia',
#        'Zimbabwe', 'Myanmar', 'South-Central Colombia', '15% Sumatra',
#        'East And Central Africa', 'Various Latin American Origins',
#        'Southwestern Mexico', 'Eastern Jamaica', 'Western Guatemala',
#        'Eastern Zimbabwe', 'Southern And Western Ethiopia',
#        'Southern Laos', 'Souther Ethiopia', 'Souther Ecuador',
#        'East-Central Brazil', 'South-Central Brazil', 'Southern Tanzania',
#        'Southern Peru', 'Eastern Papua New Guinea', 'Southeastern Mexico',
#        'Central Northwest Colombia', 'Central Honduras', 'Usa',
#        'Southeastern Peru', 'Western Highlands Of Papua New Guinea',
#        'Southern Malawi', 'North-Central Guatemala',
#        'South Central Guatemala', 'Highlands Of Papua New Guinea',
#        'Northern Sumatra', 'Central Papua New Guinea',
#        'Asia And Latin America', 'Northwestern Guatemala',
#        'Southwestern Guatemala', 'Minas Gerais State', 'Eastern Java',
#        'Indonesia And Costa Rica', 'Central And South America',
#        'Southern Honduras', 'Indonesia And Central America', 'GuatemalaE',
#        'East Africa', 'Central Zambia', 'Northeastern Ethiopia'],
#       dtype=object)

# %%
# Let's look at all of the entries that contain 'South'.
south = coffee_origins[coffee_origins['coffee_origin'].str.contains('South', na=False)]
south['coffee_origin'].unique().tolist()
# Out:
# ['Southern Ethiopia',
#  'Southwest Vietnam',
#  'South-Central Kenya',
#  'South-Central Ethiopia',
#  'Southern Colombia',
#  'Southern',
#  'Southwestern Tanzania',
#  'South-Central Guatemala',
#  'Southern Rwanda',
#  'Southwestern Kenya',
#  'Southwestern Ethiopia',
#  'Southwestern Colombia',
#  'South Africa',
#  'Southeastern Ethiopia',
#  'South America',
#  'South-Eastern Ecuador',
#  'Southern Ecuador',
#  'Southeastern Brazil',
#  'Southeastern El Salvador',
#  'Southern Costa Rica',
#  'South-Central Rwanda',
#  'Southwestern Colombianar',
#  'Southwest Ethiopia',
#  'Southwest Uganda',
#  'Southern Province,Rwanda',
#  'South-Central Kenyamur',
#  'Southern India',
#  'South-Central Colombia',
#  'Southwestern Mexico',
#  'Southern And Western Ethiopia',
#  'Southern Laos',
#  'Souther Ethiopia',
#  'Souther Ecuador',
#  'South-Central Brazil',
#  'Southern Tanzania',
#  'Southern Peru',
#  'Southeastern Mexico',
#  'Southeastern Peru',
#  'Southern Malawi',
#  'South Central Guatemala',
#  'Southwestern Guatemala',
#  'Central And South America',
#  'Southern Honduras']

# %%
# Since only a few countries have two-word names, I'm going to temporarily convert them to one-word names
# until the end of this notebook.
double_dictionary = {'El Salvador': 'ElSalvador', 'Costa Rica': 'CostaRica', 'Papua New Guinea' : 'PapuaNewGuinea', 'Democratic Republic Of The Congo' : 'Congo', 'South Africa' : 'SouthAfrica'}

for key in double_dictionary.keys():
    coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace(key, double_dictionary[key])

coffee_origins['coffee_origin'].unique()
# Out:
# array(['Bolivia', 'Ethiopia', 'Southern Ethiopia', 'Colombia',
#        'Guatemala', 'PapuaNewGuinea', 'Northern Philippines', 'Brazil',
#        'Peru', 'ElSalvador', 'Tanzania', 'Kenya', 'Panama', 'Congo',
#        'CostaRica', 'Ecuador', 'Southwest Vietnam', 'Indonesia',
#        'Central ElSalvador', 'Nicaragua', 'Mexico', 'Rwanda', 'Haiti',
#        'Vietnam', 'Not Disclosed', 'South-Central Kenya',
#        'Northern Nicaragua', 'Burundi', 'Honduras',
#        'South-Central Ethiopia', 'Western Panama', 'Philippines',
#        'Southern Colombia', 'Yemen', 'Huila Colombia', 'Southern',
#        'Uganda', 'Africa', 'Apaneca Ilamatepec Mountain Range',
#        'Democratic Republic Of Congo', 'Latin America',
#        'Northern Burundi', 'Central America', 'East Malaysia',
#        'The Philippines', 'Zambia', 'Southwestern Tanzania', 'Thailand',
#        'Northern Tanzania', 'Dominican Republic', 'Sumatra',
#        'Central Kenya', 'South-Central Guatemala', 'Western Rwanda',
#        'Gedeo Zone', 'Taiwan', 'Northern Peru', 'Southern Rwanda',
#        'Southwestern Kenya', 'Southwestern Ethiopia', 'Madagascar',
#        'Southwestern Colombia', 'Northern Guatemala', 'Drc Congo',
#        'Nepal', 'Central Rwanda', 'The Congo', 'China', 'SouthAfrica',
#        'Western Kenya', 'Far Western Panama', 'Southeastern Ethiopia',
#        'South America', 'West-Central Bolivia', 'Central Peru',
#        'North-Central Ecuador', 'South-Eastern Ecuador',
#        'North-Central Peru', 'Southern Ecuador',
#        'Harar (Also Harrar) Growing Region Of Eastern Ethiopia',
#        'Southeastern Brazil', 'West-Central Colombia', 'Malaysia',
#        'Central Colombia', 'Eastern Highlands,PapuaNewGuinea',
#        'Western Colombia', 'Northwestern ElSalvador',
#        'Southeastern ElSalvador', 'Jamaica', 'Southern CostaRica',
#        'North-Central Yemen', 'Northern Thailand',
#        'Brazil And Four Other Origins', 'Central Guatemala',
#        'Kenya Gatugi Ab', 'South-Central Rwanda', 'Center-West Colombia',
#        'Northern Ecuador', 'Northwest ElSalvador',
#        'Ethiopia Natural Yirgacheffe Adado Shara',
#        'Southwestern Colombianar', 'Central Yemen', 'Southwest Ethiopia',
#        'Southwest Uganda', 'Central CostaRica', 'Western Uganda',
#        'Western Ethiopia', 'Southern Province,Rwanda', 'Eastern Ethiopia',
#        'Western ElSalvador', 'North-Central Nicaragua',
#        'Central Puerto Rico', 'South-Central Kenyamur',
#        'Colombia And Ethiopia', 'Northern Rwanda', 'Southern India',
#        'Northwestern Colombia',
#        'Colombia Aromas Del Sur Palestina Micro-Lot', 'Western Bolivia',
#        'Zimbabwe', 'Myanmar', 'South-Central Colombia', '15% Sumatra',
#        'East And Central Africa', 'Various Latin American Origins',
#        'Southwestern Mexico', 'Eastern Jamaica', 'Western Guatemala',
#        'Eastern Zimbabwe', 'Southern And Western Ethiopia',
#        'Southern Laos', 'Souther Ethiopia', 'Souther Ecuador',
#        'East-Central Brazil', 'South-Central Brazil', 'Southern Tanzania',
#        'Southern Peru', 'Eastern PapuaNewGuinea', 'Southeastern Mexico',
#        'Central Northwest Colombia', 'Central Honduras', 'Usa',
#        'Southeastern Peru', 'Western Highlands Of PapuaNewGuinea',
#        'Southern Malawi', 'North-Central Guatemala',
#        'South Central Guatemala', 'Highlands Of PapuaNewGuinea',
#        'Northern Sumatra', 'Central PapuaNewGuinea',
#        'Asia And Latin America', 'Northwestern Guatemala',
#        'Southwestern Guatemala', 'Minas Gerais State', 'Eastern Java',
#        'Indonesia And CostaRica', 'Central And South America',
#        'Southern Honduras', 'Indonesia And Central America', 'GuatemalaE',
#        'East Africa', 'Central Zambia', 'Northeastern Ethiopia'],
#       dtype=object)

# %%
cardinal_varieties = ['Southern', 'Central', 'Southwestern', 'Southeastern', 'South-Central', 'Souther', 'Southwest'
                    , 'Northern', 'Northwestern', 'Northeastern', 'North-Central', 'Norther', 'Northwest',
                     'Eastern', 'East', 'Far', 'Western', 'West', '-', 'Not Disclosed']
for item in cardinal_varieties:
    coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace(item, '')
# coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace('Southern ', '')
coffee_origins['coffee_origin'].unique().tolist()
# Out:
# ['Bolivia',
#  'Ethiopia',
#  ' Ethiopia',
#  'Colombia',
#  'Guatemala',
#  'PapuaNewGuinea',
#  ' Philippines',
#  'Brazil',
#  'Peru',
#  'ElSalvador',
#  'Tanzania',
#  'Kenya',
#  'Panama',
#  'Congo',
#  'CostaRica',
#  'Ecuador',
#  ' Vietnam',
#  'Indonesia',
#  ' ElSalvador',
#  'Nicaragua',
#  'Mexico',
#  'Rwanda',
#  'Haiti',
#  'Vietnam',
#  '',
#  'South Kenya',
#  ' Nicaragua',
#  'Burundi',
#  'Honduras',
#  'South Ethiopia',
#  ' Panama',
#  'Philippines',
#  ' Colombia',
#  'Yemen',
#  'Huila Colombia',
#  'Uganda',
#  'Africa',
#  'Apaneca Ilamatepec Mountain Range',
#  'Democratic Republic Of Congo',
#  'Latin America',
#  ' Burundi',
#  ' America',
#  ' Malaysia',
#  'The Philippines',
#  'Zambia',
#  ' Tanzania',
#  'Thailand',
#  'Dominican Republic',
#  'Sumatra',
#  ' Kenya',
#  'South Guatemala',
#  ' Rwanda',
#  'Gedeo Zone',
#  'Taiwan',
#  ' Peru',
#  'Madagascar',
#  ' Guatemala',
#  'Drc Congo',
#  'Nepal',
#  'The Congo',
#  'China',
#  'SouthAfrica',
#  '  Panama',
#  'South America',
#  ' Bolivia',
#  'North Ecuador',
#  'South Ecuador',
#  'North Peru',
#  ' Ecuador',
#  'Harar (Also Harrar) Growing Region Of  Ethiopia',
#  ' Brazil',
#  'Malaysia',
#  ' Highlands,PapuaNewGuinea',
#  'Jamaica',
#  ' CostaRica',
#  'North Yemen',
#  ' Thailand',
#  'Brazil And Four Other Origins',
#  'Kenya Gatugi Ab',
#  'South Rwanda',
#  'Center Colombia',
#  'Ethiopia Natural Yirgacheffe Adado Shara',
#  ' Colombianar',
#  ' Yemen',
#  ' Uganda',
#  ' Province,Rwanda',
#  'North Nicaragua',
#  ' Puerto Rico',
#  'South Kenyamur',
#  'Colombia And Ethiopia',
#  ' India',
#  'Colombia Aromas Del Sur Palestina MicroLot',
#  'Zimbabwe',
#  'Myanmar',
#  'South Colombia',
#  '15% Sumatra',
#  ' And  Africa',
#  'Various Latin American Origins',
#  ' Mexico',
#  ' Jamaica',
#  ' Zimbabwe',
#  ' And  Ethiopia',
#  ' Laos',
#  'South Brazil',
#  ' PapuaNewGuinea',
#  '  Colombia',
#  ' Honduras',
#  'Usa',
#  ' Highlands Of PapuaNewGuinea',
#  ' Malawi',
#  'North Guatemala',
#  'South  Guatemala',
#  'Highlands Of PapuaNewGuinea',
#  ' Sumatra',
#  'Asia And Latin America',
#  'Minas Gerais State',
#  ' Java',
#  'Indonesia And CostaRica',
#  ' And South America',
#  'Indonesia And  America',
#  'GuatemalaE',
#  ' Africa',
#  ' Zambia']

# %%
# This data is definitely in need of some stripping again.
coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.strip()
coffee_origins['coffee_origin'].unique().tolist()
# We're getting closer!
# Out:
# ['Bolivia',
#  'Ethiopia',
#  'Colombia',
#  'Guatemala',
#  'PapuaNewGuinea',
#  'Philippines',
#  'Brazil',
#  'Peru',
#  'ElSalvador',
#  'Tanzania',
#  'Kenya',
#  'Panama',
#  'Congo',
#  'CostaRica',
#  'Ecuador',
#  'Vietnam',
#  'Indonesia',
#  'Nicaragua',
#  'Mexico',
#  'Rwanda',
#  'Haiti',
#  '',
#  'South Kenya',
#  'Burundi',
#  'Honduras',
#  'South Ethiopia',
#  'Yemen',
#  'Huila Colombia',
#  'Uganda',
#  'Africa',
#  'Apaneca Ilamatepec Mountain Range',
#  'Democratic Republic Of Congo',
#  'Latin America',
#  'America',
#  'Malaysia',
#  'The Philippines',
#  'Zambia',
#  'Thailand',
#  'Dominican Republic',
#  'Sumatra',
#  'South Guatemala',
#  'Gedeo Zone',
#  'Taiwan',
#  'Madagascar',
#  'Drc Congo',
#  'Nepal',
#  'The Congo',
#  'China',
#  'SouthAfrica',
#  'South America',
#  'North Ecuador',
#  'South Ecuador',
#  'North Peru',
#  'Harar (Also Harrar) Growing Region Of  Ethiopia',
#  'Highlands,PapuaNewGuinea',
#  'Jamaica',
#  'North Yemen',
#  'Brazil And Four Other Origins',
#  'Kenya Gatugi Ab',
#  'South Rwanda',
#  'Center Colombia',
#  'Ethiopia Natural Yirgacheffe Adado Shara',
#  'Colombianar',
#  'Province,Rwanda',
#  'North Nicaragua',
#  'Puerto Rico',
#  'South Kenyamur',
#  'Colombia And Ethiopia',
#  'India',
#  'Colombia Aromas Del Sur Palestina MicroLot',
#  'Zimbabwe',
#  'Myanmar',
#  'South Colombia',
#  '15% Sumatra',
#  'And  Africa',
#  'Various Latin American Origins',
#  'And  Ethiopia',
#  'Laos',
#  'South Brazil',
#  'Usa',
#  'Highlands Of PapuaNewGuinea',
#  'Malawi',
#  'North Guatemala',
#  'South  Guatemala',
#  'Asia And Latin America',
#  'Minas Gerais State',
#  'Java',
#  'Indonesia And CostaRica',
#  'And South America',
#  'Indonesia And  America',
#  'GuatemalaE']

# %%
# And while we're at it, I'm going to remove a few of these that don't belong or don't make sense:
nuh_uh = ['Indonesia And  America','Indonesia And CostaRica','15% Sumatra','Puerto Rico','Latin America',
 'Africa', '','America','South America','Brazil And Four Other Origins','Colombia And Ethiopia','And  Africa','Various Latin American Origins','And South America','Asia And Latin America','Usa',]
for item in nuh_uh:
    coffee_origins = coffee_origins[~(coffee_origins['coffee_origin'] == item)]
# coffee_origins = coffee_origins[~(coffee_origins['coffee_origin'].str.contains('South America', na=False))]
# coffee_origins = coffee_origins[~(coffee_origins['coffee_origin'] == 'Southern')]
coffee_origins['coffee_origin'].unique().tolist()
# Out:
# ['Bolivia',
#  'Ethiopia',
#  'Colombia',
#  'Guatemala',
#  'PapuaNewGuinea',
#  'Philippines',
#  'Brazil',
#  'Peru',
#  'ElSalvador',
#  'Tanzania',
#  'Kenya',
#  'Panama',
#  'Congo',
#  'CostaRica',
#  'Ecuador',
#  'Vietnam',
#  'Indonesia',
#  'Nicaragua',
#  'Mexico',
#  'Rwanda',
#  'Haiti',
#  'South Kenya',
#  'Burundi',
#  'Honduras',
#  'South Ethiopia',
#  'Yemen',
#  'Huila Colombia',
#  'Uganda',
#  'Apaneca Ilamatepec Mountain Range',
#  'Democratic Republic Of Congo',
#  'Malaysia',
#  'The Philippines',
#  'Zambia',
#  'Thailand',
#  'Dominican Republic',
#  'Sumatra',
#  'South Guatemala',
#  'Gedeo Zone',
#  'Taiwan',
#  'Madagascar',
#  'Drc Congo',
#  'Nepal',
#  'The Congo',
#  'China',
#  'SouthAfrica',
#  'North Ecuador',
#  'South Ecuador',
#  'North Peru',
#  'Harar (Also Harrar) Growing Region Of  Ethiopia',
#  'Highlands,PapuaNewGuinea',
#  'Jamaica',
#  'North Yemen',
#  'Kenya Gatugi Ab',
#  'South Rwanda',
#  'Center Colombia',
#  'Ethiopia Natural Yirgacheffe Adado Shara',
#  'Colombianar',
#  'Province,Rwanda',
#  'North Nicaragua',
#  'South Kenyamur',
#  'India',
#  'Colombia Aromas Del Sur Palestina MicroLot',
#  'Zimbabwe',
#  'Myanmar',
#  'South Colombia',
#  'And  Ethiopia',
#  'Laos',
#  'South Brazil',
#  'Highlands Of PapuaNewGuinea',
#  'Malawi',
#  'North Guatemala',
#  'South  Guatemala',
#  'Minas Gerais State',
#  'Java',
#  'GuatemalaE']

# %%
# Time to start grouping countries we see a lot in this list.
kenyas = coffee_origins[coffee_origins['coffee_origin'].str.contains('enya', na=False)]
kenyas['coffee_origin'].unique().tolist()
# Out:
# ['Kenya', 'South Kenya', 'Kenya Gatugi Ab', 'South Kenyamur']

# %%
for item in kenyas['coffee_origin'].unique().tolist():
    coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace(item, 'Kenya')
    
coffee_origins['coffee_origin'].unique().tolist()
# Hmmm.. Looks like 'Kenyamur' didn't end up in the kenya list for some reason.
coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace('Kenyamur', 'Kenya')

# %%
guatemalas = coffee_origins[coffee_origins['coffee_origin'].str.contains('Guatemala', na=False)]
brazils = coffee_origins[coffee_origins['coffee_origin'].str.contains('Brazil', na=False)]
ethiopias = coffee_origins[coffee_origins['coffee_origin'].str.contains('Ethiopia', na=False)]
columbias = coffee_origins[coffee_origins['coffee_origin'].str.contains('Columbia', na=False)]
nicaraguas = coffee_origins[coffee_origins['coffee_origin'].str.contains('Nicaragua', na=False)]
ecuadors = coffee_origins[coffee_origins['coffee_origin'].str.contains('Ecuador', na=False)]
perus = coffee_origins[coffee_origins['coffee_origin'].str.contains('Peru', na=False)]
yemens = coffee_origins[coffee_origins['coffee_origin'].str.contains('Yemen', na=False)]
rwandas = coffee_origins[coffee_origins['coffee_origin'].str.contains('Rwanda', na=False)]
yirgacheffes = coffee_origins[coffee_origins['coffee_origin'].str.contains('Yirgacheffe', na=False)]

for item in guatemalas['coffee_origin'].unique().tolist():
    coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace(item, 'Guatemala')
for item in brazils['coffee_origin'].unique().tolist():
    coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace(item, 'Brazil')
for item in ethiopias['coffee_origin'].unique().tolist():
    coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace(item, 'Ethiopia')
for item in columbias['coffee_origin'].unique().tolist():
    coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace(item, 'Columbia')
for item in nicaraguas['coffee_origin'].unique().tolist():
    coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace(item, 'Nicaragua')
for item in ecuadors['coffee_origin'].unique().tolist():
    coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace(item, 'Ecaudor')
for item in perus['coffee_origin'].unique().tolist():
    coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace(item, 'Peru')
for item in yemens['coffee_origin'].unique().tolist():
    coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace(item, 'Yemen')
for item in rwandas['coffee_origin'].unique().tolist():
    coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace(item, 'Rwanda')
for item in yirgacheffes['coffee_origin'].unique().tolist():
    coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace(item, 'Ethiopia')

coffee_origins['coffee_origin'].unique().tolist()
# Out:
# C:\Users\samia\AppData\Local\Temp\ipykernel_10744\2133013799.py:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace(item, 'Ethiopia')
# ['Bolivia',
#  'Ethiopia',
#  'Colombia',
#  'Guatemala',
#  'PapuaNewGuinea',
#  'Philippines',
#  'Brazil',
#  'Peru',
#  'ElSalvador',
#  'Tanzania',
#  'Kenya',
#  'Panama',
#  'Congo',
#  'CostaRica',
#  'Ecaudor',
#  'Vietnam',
#  'Indonesia',
#  'Nicaragua',
#  'Mexico',
#  'Rwanda',
#  'Haiti',
#  'Burundi',
#  'Honduras',
#  'Yemen',
#  'Huila Colombia',
#  'Uganda',
#  'Apaneca Ilamatepec Mountain Range',
#  'Democratic Republic Of Congo',
#  'Malaysia',
#  'The Philippines',
#  'Zambia',
#  'Thailand',
#  'Dominican Republic',
#  'Sumatra',
#  'Gedeo Zone',
#  'Taiwan',
#  'Madagascar',
#  'Drc Congo',
#  'Nepal',
#  'The Congo',
#  'China',
#  'SouthAfrica',
#  'North Ecaudor',
#  'South Ecaudor',
#  'Harar (Also Harrar) Growing Region Of  Ethiopia',
#  'Highlands,PapuaNewGuinea',
#  'Jamaica',
#  'Center Colombia',
#  'Colombianar',
#  'India',
#  'Colombia Aromas Del Sur Palestina MicroLot',
#  'Zimbabwe',
#  'Myanmar',
#  'South Colombia',
#  'Laos',
#  'Highlands Of PapuaNewGuinea',
#  'Malawi',
#  'Minas Gerais State',
#  'Java']

# %%
# I missed some alternative spellings!

colombias = coffee_origins[coffee_origins['coffee_origin'].str.contains('Colombia', na=False)]
for item in colombias['coffee_origin'].unique().tolist():
    coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace(item, 'Colombia')
ecaudors = coffee_origins[coffee_origins['coffee_origin'].str.contains('Ecaudor', na=False)]
for item in ecaudors['coffee_origin'].unique().tolist():
    coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace(item, 'Ecuador')
pngs = coffee_origins[coffee_origins['coffee_origin'].str.contains('PapuaNewGuinea', na=False)]
for item in pngs['coffee_origin'].unique().tolist():
    coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace(item, 'PapuaNewGuinea')
congo = coffee_origins[coffee_origins['coffee_origin'].str.contains('Congo', na=False)]
for item in congo['coffee_origin'].unique().tolist():
    coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace(item, 'Congo')
    
    
# And a few that need extra attention:
coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace('Harar (Also Harrar) Growing Region Of  Ethiopia', 'Ethiopia')
coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace('The Philippines', 'Philippines')

# And here are a few areas I had to look up:
coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace('Apaneca Ilamatepec Mountain Range', 'ElSalvador')
coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace('Minas Gerais State', 'Brazil')
coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace('Gedeo Zone', 'Ethiopia')

coffee_origins['coffee_origin'].unique().tolist()
# Out:
# C:\Users\samia\AppData\Local\Temp\ipykernel_10744\786610421.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace('Harar (Also Harrar) Growing Region Of  Ethiopia', 'Ethiopia')
# ['Bolivia',
#  'Ethiopia',
#  'Colombia',
#  'Guatemala',
#  'PapuaNewGuinea',
#  'Philippines',
#  'Brazil',
#  'Peru',
#  'ElSalvador',
#  'Tanzania',
#  'Kenya',
#  'Panama',
#  'Congo',
#  'CostaRica',
#  'Ecuador',
#  'Vietnam',
#  'Indonesia',
#  'Nicaragua',
#  'Mexico',
#  'Rwanda',
#  'Haiti',
#  'Burundi',
#  'Honduras',
#  'Yemen',
#  'Uganda',
#  'Malaysia',
#  'Zambia',
#  'Thailand',
#  'Dominican Republic',
#  'Sumatra',
#  'Taiwan',
#  'Madagascar',
#  'Nepal',
#  'China',
#  'SouthAfrica',
#  'North Ecuador',
#  'South Ecuador',
#  'Harar (Also Harrar) Growing Region Of  Ethiopia',
#  'Jamaica',
#  'India',
#  'Zimbabwe',
#  'Myanmar',
#  'Laos',
#  'Malawi',
#  'Java']

# %%
# Hmm..
coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace('Dominican Republic', 'DominicanRepublic')

coffee_origins['coffee_origin'].unique().tolist()
# Out:
# ['Bolivia',
#  'Ethiopia',
#  'Colombia',
#  'Guatemala',
#  'PapuaNewGuinea',
#  'Philippines',
#  'Brazil',
#  'Peru',
#  'ElSalvador',
#  'Tanzania',
#  'Kenya',
#  'Panama',
#  'Congo',
#  'CostaRica',
#  'Ecuador',
#  'Vietnam',
#  'Indonesia',
#  'Nicaragua',
#  'Mexico',
#  'Rwanda',
#  'Haiti',
#  'Burundi',
#  'Honduras',
#  'Yemen',
#  'Uganda',
#  'Malaysia',
#  'Zambia',
#  'Thailand',
#  'DominicanRepublic',
#  'Sumatra',
#  'Taiwan',
#  'Madagascar',
#  'Nepal',
#  'China',
#  'SouthAfrica',
#  'North Ecuador',
#  'South Ecuador',
#  'Harar (Also Harrar) Growing Region Of  Ethiopia',
#  'Jamaica',
#  'India',
#  'Zimbabwe',
#  'Myanmar',
#  'Laos',
#  'Malawi',
#  'Java']

# %%
coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.split(' ')
coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str[-1]

coffee_origins['coffee_origin'].unique().tolist()
# Out:
# ['Bolivia',
#  'Ethiopia',
#  'Colombia',
#  'Guatemala',
#  'PapuaNewGuinea',
#  'Philippines',
#  'Brazil',
#  'Peru',
#  'ElSalvador',
#  'Tanzania',
#  'Kenya',
#  'Panama',
#  'Congo',
#  'CostaRica',
#  'Ecuador',
#  'Vietnam',
#  'Indonesia',
#  'Nicaragua',
#  'Mexico',
#  'Rwanda',
#  'Haiti',
#  'Burundi',
#  'Honduras',
#  'Yemen',
#  'Uganda',
#  'Malaysia',
#  'Zambia',
#  'Thailand',
#  'DominicanRepublic',
#  'Sumatra',
#  'Taiwan',
#  'Madagascar',
#  'Nepal',
#  'China',
#  'SouthAfrica',
#  'Jamaica',
#  'India',
#  'Zimbabwe',
#  'Myanmar',
#  'Laos',
#  'Malawi',
#  'Java']

# %%
# Yay! Now I'll un-squash all of the countries with multi-word names and save this as a csv.
coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace('DominicanRepublic', 'Dominican Republic')
coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace('SouthAfrica', 'South Africa')
coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace('CostaRica', 'Costa Rica')
coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace('ElSalvador', 'El Salvador')
coffee_origins['coffee_origin'] = coffee_origins['coffee_origin'].str.replace('PapuaNewGuinea', 'Papua New Guinea')
coffee_origins.head()
# Out:
#                                 title  rating  aftertaste  aroma  body  \
# 0             Bolivia Manantial Gesha      93         8.0      9     8
# 1          Ethiopia Gera Genji Challa      94         8.0      9     9
# 2        Yirgacheffe Mengesha Natural      94         8.0      9     9
# 3  Tropical Summer Colombia La Sierra      93         8.0      9     8
# 4                     Tinamit Tolimán      93         8.0      9     9
#
#    flavor                                   blind_assessment coffee_origin  \
# 0       9  Richly aromatic, floral-toned. Magnolia, cocoa...       Bolivia
# 1       9  Delicately aromatic, complex. Lilac, cocoa nib...      Ethiopia
# 2       9  High-toned, fruit-driven. Boysenberry, pear, c...      Ethiopia
# 3       9  Fruit-driven, crisply chocolaty. Goji berry, d...      Colombia
# 4       9  Deeply sweet-tart, chocolate-toned. Dark choco...     Guatemala
#
#          est_price   roast_level                     roaster  \
# 0  30.00/12 ounces  Medium-Light  Red Rooster Coffee Roaster
# 1  28.00/12 ounces  Medium-Light               Mostra Coffee
# 2  20.50/12 ounces  Medium-Light               Regent Coffee
# 3   18.99/8 ounces  Medium-Light        Merge Coffee Company
# 4  16.00/12 ounces  Medium-Light                El Gran Cafe
#
#          roaster_location  dollars_per_ounce
# 0         Floyd, Virginia           2.500000
# 1   San Diego, California           2.333333
# 2    Glendale, California           1.708333
# 3  Harrisonburg, Virginia           2.373750
# 4      Antigua, Guatemala           1.333333

# %%
coffee_origins['title'] = coffee_origins['title'].str.replace(',', '')
coffee_origins['blind_assessment'] = coffee_origins['blind_assessment'].str.replace(',', '')
coffee_origins['roaster'] = coffee_origins['roaster'].str.replace(',', '')
coffee_origins['roaster_location'] = coffee_origins['roaster_location'].str.replace(',', '')
coffee_origins.head()
# Out:
#                                 title  rating  aftertaste  aroma  body  \
# 0             Bolivia Manantial Gesha      93         8.0      9     8
# 1          Ethiopia Gera Genji Challa      94         8.0      9     9
# 2        Yirgacheffe Mengesha Natural      94         8.0      9     9
# 3  Tropical Summer Colombia La Sierra      93         8.0      9     8
# 4                     Tinamit Tolimán      93         8.0      9     9
#
#    flavor                                   blind_assessment coffee_origin  \
# 0       9  Richly aromatic floral-toned. Magnolia cocoa n...       Bolivia
# 1       9  Delicately aromatic complex. Lilac cocoa nib p...      Ethiopia
# 2       9  High-toned fruit-driven. Boysenberry pear coco...      Ethiopia
# 3       9  Fruit-driven crisply chocolaty. Goji berry dri...      Colombia
# 4       9  Deeply sweet-tart chocolate-toned. Dark chocol...     Guatemala
#
#          est_price   roast_level                     roaster  \
# 0  30.00/12 ounces  Medium-Light  Red Rooster Coffee Roaster
# 1  28.00/12 ounces  Medium-Light               Mostra Coffee
# 2  20.50/12 ounces  Medium-Light               Regent Coffee
# 3   18.99/8 ounces  Medium-Light        Merge Coffee Company
# 4  16.00/12 ounces  Medium-Light                El Gran Cafe
#
#         roaster_location  dollars_per_ounce
# 0         Floyd Virginia           2.500000
# 1   San Diego California           2.333333
# 2    Glendale California           1.708333
# 3  Harrisonburg Virginia           2.373750
# 4      Antigua Guatemala           1.333333

# %%
coffee_origins.to_csv('coffee_origins_tableau.csv')
